# %%
import pandas as pd

# %%
grades_df = pd.read_csv('2021.csv')
grades_df.head(5)
# Out:
#          ID Case Number                    Date                      Block  \
# 0  12571973    JE482457  12/19/2021 07:23:00 AM          042XX S MOZART ST
# 1  12343475    JE202728  04/16/2021 08:45:00 PM          056XX N RIDGE AVE
# 2  12602803    JF125633  10/21/2021 11:00:00 AM   083XX S STONY ISLAND AVE
# 3  12540388    JE444591  11/14/2021 06:00:00 AM  086XX S COTTAGE GROVE AVE
# 4  12541139    JE445494  11/14/2021 04:00:00 AM            034XX W 38TH ST
#
#    IUCR   Primary Type              Description Location Description  Arrest  \
# 0  0460        BATTERY                   SIMPLE             SIDEWALK    True
# 1  0820          THEFT           $500 AND UNDER      OTHER (SPECIFY)   False
# 2  500E  OTHER OFFENSE            EAVESDROPPING      OTHER (SPECIFY)   False
# 3  0850          THEFT            ATTEMPT THEFT    CONVENIENCE STORE   False
# 4  0486        BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
#
# ...

# %%
import json
results = grades_df.head(5).to_json(orient="records")
parsed = json.loads(results)
print(json.dumps(parsed, indent=4))
# Out:
# [
#     {
#         "ID": 12571973,
#         "Case Number": "JE482457",
#         "Date": "12/19/2021 07:23:00 AM",
#         "Block": "042XX S MOZART ST",
#         "IUCR": "0460",
#         "Primary Type": "BATTERY",
#         "Description": "SIMPLE",
#         "Location Description": "SIDEWALK",
#         "Arrest": true,
#         "Domestic": true,
#         "Beat": 921,
#         "District": 9.0,
#         "Ward": 15.0,
#         "Community Area": 58.0,
#         "FBI Code": "08B",
#         "X Coordinate": 1158067.0,
#         "Y Coordinate": 1876425.0,
#         "Year": 2021,
#         "Updated On": "09/12/2022 04:45:45 PM",
#         "Latitude": 41.81665685,
#         "Longitude": -87.695688608,
#         "Location": "(41.81665685, -87.695688608)"
#     },
#     {
#         "ID": 12343475,
#         "Case Number": "JE202728",
#         "Date": "04/16/2021 08:45:00 PM",
#         "Block": "056XX N RIDGE AVE",
#         "IUCR": "0820",
#         "Primary Type": "THEFT",
# ...

# %%
results = grades_df.head(5).to_dict(orient='records')
results
# Out:
# [{'ID': 12571973,
#   'Case Number': 'JE482457',
#   'Date': '12/19/2021 07:23:00 AM',
#   'Block': '042XX S MOZART ST',
#   'IUCR': '0460',
#   'Primary Type': 'BATTERY',
#   'Description': 'SIMPLE',
#   'Location Description': 'SIDEWALK',
#   'Arrest': True,
#   'Domestic': True,
#   'Beat': 921,
#   'District': 9.0,
#   'Ward': 15.0,
#   'Community Area': 58.0,
#   'FBI Code': '08B',
#   'X Coordinate': 1158067.0,
#   'Y Coordinate': 1876425.0,
#   'Year': 2021,
#   'Updated On': '09/12/2022 04:45:45 PM',
#   'Latitude': 41.81665685,
#   'Longitude': -87.695688608,
#   'Location': '(41.81665685, -87.695688608)'},
#  {'ID': 12343475,
#   'Case Number': 'JE202728',
#   'Date': '04/16/2021 08:45:00 PM',
#   'Block': '056XX N RIDGE AVE',
#   'IUCR': '0820',
#   'Primary Type': 'THEFT',
#   'Description': '$500 AND UNDER',
#   'Location Description': 'OTHER (SPECIFY)',
#   'Arrest': False,
#   'Domestic': False,
#   'Beat': 2013,
#   'District': 20.0,
#   'Ward': 48.0,
# ...
